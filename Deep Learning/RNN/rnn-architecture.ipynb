# %%
import tensorflow
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN

# %%
model = Sequential()

model.add(SimpleRNN(3, input_shape=(4,5)))
model.add(Dense(1, activation="sigmoid"))

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn_1 (SimpleRNN)        │ (None, 3)              │            27 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             4 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 31 (124.00 B)
#  Trainable params: 31 (124.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
print(model.get_weights()[0].shape)
print(model.get_weights()[0])
# Out:
# (5, 3)
# [[ 0.32186395 -0.35770494 -0.69390243]
#  [ 0.49400216  0.15033573 -0.4769639 ]
#  [ 0.5273157  -0.39429092 -0.8395373 ]
#  [ 0.6447187   0.8363084  -0.40063614]
#  [-0.6310022  -0.46688828 -0.6511562 ]]

# %%
print(model.get_weights()[1].shape)
print(model.get_weights()[1])
# Out:
# (3, 3)
# [[-0.42060256  0.83085    -0.3643921 ]
#  [-0.89286816 -0.30786133  0.32864553]
#  [ 0.16087297  0.4635832   0.87132686]]

# %%
print(model.get_weights()[2].shape)
print(model.get_weights()[2])
# Out:
# (3,)
# [0. 0. 0.]

# %%
print(model.get_weights()[3].shape)
print(model.get_weights()[4])
# Out:
# (3, 1)
# [0.]

# %%
print(model.get_weights()[4].shape)
print(model.get_weights()[4])
# Out:
# (1,)
# [0.]
